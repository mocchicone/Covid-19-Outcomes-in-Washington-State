# %%
import pandas as pd
import numpy as np
import datetime
from functools import reduce

data = pd.read_csv("sars_cases.csv")
death = pd.read_csv("sars_deaths.csv")
hospitalization = pd.read_csv("sars_hospitalizations.csv")
#adding suffix
hospitalization = hospitalization.add_suffix("_hospitalization")
census = pd.read_csv("census_politics_merge_mike2.csv")

cleandata = pd.DataFrame.copy(data)

day = pd.Series(cleandata["WeekStartDate"]).str.split("/").str[1]
month = pd.Series(cleandata["WeekStartDate"]).str.split("/").str[0]
year = pd.Series(cleandata["WeekStartDate"]).str.split("/").str[2]

month = month.map(lambda x: x.zfill(2))
day = day.map(lambda x: x.zfill(2))


cleandata["WeekStartDate"] = year + "-" + month + "-" + day




dataframes = [cleandata, death, hospitalization]

#mergedf = reduce(lambda  left,right: pd.merge(left,right,on=['County', "WeekStartDate"], suffixes= ("_cases", "_death", "_hospitalization"), how='outer'), dataframes)

mergedf = pd.merge(cleandata, death, on = ["County", "WeekStartDate"], suffixes = ("_cases", "_death"), how= "outer", indicator = True)#.fillna(0)
#mergedf[mergedf["_merge"] == "both"]

merge1 = pd.DataFrame(mergedf)

mergedf2 = pd.merge(merge1, hospitalization, left_on = "County", right_on = "County_hospitalization", how = "outer", indicator = "exists")

#mergedf.fillna(0)

#mergedf2.to_csv("test.csv")
mergedf2
# Out:
#             County WeekStartDate  NewPos_All  Age 0-19_cases  Age 20-39_cases  \
# 0     Adams County    2020-03-08           4               0                1
# 1     Adams County    2020-03-08           4               0                1
# 2     Adams County    2020-03-08           4               0                1
# 3     Adams County    2020-03-08           4               0                1
# 4     Adams County    2020-03-08           4               0                1
# ...            ...           ...         ...             ...              ...
# 6547    Unassigned    2020-06-14           9               0                7
# 6548    Unassigned    2020-06-21          27               2               12
# 6549    Unassigned    2020-06-21          27               2               12
# 6550    Unassigned    2020-06-28          81               7               40
# 6551    Unassigned    2020-06-28          81               7               40
#
#       Age 40-59_cases  Age 60-79_cases  Age 80+_cases  Positive UnkAge_cases  \
# 0                   1                2              0                      0
# 1                   1                2              0                      0
# 2                   1                2              0                      0
# 3                   1                2              0                      0
# 4                   1                2              0                      0
# ...               ...              ...            ...                    ...
# 6547                1                0              0                      1
# 6548                8                5              0                      0
# 6549                8                5              0                      0
# 6550               25                7              2                      0
# 6551               25                7              2                      0
#
#      dtm_updated_cases  ...  WeekStartDate_hospitalization  \
# 0       7/5/2020 15:36  ...                     2020-03-15
# 1       7/5/2020 15:36  ...                     2020-03-22
# 2       7/5/2020 15:36  ...                     2020-04-05
# 3       7/5/2020 15:36  ...                     2020-06-07
# 4       7/5/2020 15:36  ...                     2020-06-14
# ...                ...  ...                            ...
# 6547    7/5/2020 15:36  ...                     2020-06-28
# 6548    7/5/2020 15:36  ...                     2020-05-17
# 6549    7/5/2020 15:36  ...                     2020-06-28
# 6550    7/5/2020 15:36  ...                     2020-05-17
# 6551    7/5/2020 15:36  ...                     2020-06-28
#
#       Hospitalizations_hospitalization  Age 0-19_hospitalization  \
# 0                                  1.0                       0.0
# 1                                  4.0                       0.0
# 2                                  1.0                       0.0
# 3                                  1.0                       0.0
# 4                                  1.0                       0.0
# ...                                ...                       ...
# 6547                               1.0                       1.0
# 6548                               1.0                       0.0
# 6549                               1.0                       1.0
# 6550                               1.0                       0.0
# 6551                               1.0                       1.0
#
#       Age 20-39_hospitalization  Age 40-59_hospitalization  \
# 0                           0.0                        1.0
# 1                           0.0                        1.0
# 2                           0.0                        1.0
# 3                           0.0                        1.0
# 4                           0.0                        1.0
# ...                         ...                        ...
# 6547                        0.0                        0.0
# 6548                        0.0                        1.0
# 6549                        0.0                        0.0
# 6550                        0.0                        1.0
# 6551                        0.0                        0.0
#
#       Age 60-79_hospitalization  Age 80+_hospitalization  \
# 0                           0.0                      0.0
# 1                           3.0                      0.0
# 2                           0.0                      0.0
# 3                           0.0                      0.0
# 4                           0.0                      0.0
# ...                         ...                      ...
# 6547                        0.0                      0.0
# 6548                        0.0                      0.0
# 6549                        0.0                      0.0
# 6550                        0.0                      0.0
# 6551                        0.0                      0.0
#
#      Positive UnkAge_hospitalization dtm_updated_hospitalization exists
# 0                                0.0         2020/07/05 15:36:42   both
# 1                                0.0         2020/07/05 15:36:42   both
# 2                                0.0         2020/07/05 15:36:42   both
# 3                                0.0         2020/07/05 15:36:42   both
# 4                                0.0         2020/07/05 15:36:42   both
# ...                              ...                         ...    ...
# 6547                             0.0         2020/07/05 15:36:42   both
# 6548                             0.0         2020/07/05 15:36:42   both
# 6549                             0.0         2020/07/05 15:36:42   both
# 6550                             0.0         2020/07/05 15:36:42   both
# 6551                             0.0         2020/07/05 15:36:42   both
#
# [6552 rows x 30 columns]

# %%
census.head()
# Out:
#    Counter          County Political_Party  Percent Below Poverty Level  \
# 0        1    Adams County      Republican                         25.2
# 1        2   Asotin County      Republican                         13.0
# 2        3   Benton County      Republican                         12.8
# 3        4   Chelan County      Republican                         11.6
# 4        5  Clallam County      Democratic                         15.9
#
#    Household Income Median  Household Income Mean
# 0                    49142                  61370
# 1                    50423                  65079
# 2                    65650                  83941
# 3                    56135                  75117
# 4                    49913                  65858

# %%
mergedf3 = pd.merge(mergedf2, census, on = "County", how="outer")
mergedf3 = mergedf3.drop(columns=['Counter'])
mergedf3
# Out:
#                County WeekStartDate  NewPos_All  Age 0-19_cases  \
# 0        Adams County    2020-03-08         4.0             0.0
# 1        Adams County    2020-03-08         4.0             0.0
# 2        Adams County    2020-03-08         4.0             0.0
# 3        Adams County    2020-03-08         4.0             0.0
# 4        Adams County    2020-03-08         4.0             0.0
# ...               ...           ...         ...             ...
# 6550       Unassigned    2020-06-28        81.0             7.0
# 6551       Unassigned    2020-06-28        81.0             7.0
# 6552     Ferry County           NaN         NaN             NaN
# 6553  Garfield County           NaN         NaN             NaN
# 6554   Lincoln County           NaN         NaN             NaN
#
#       Age 20-39_cases  Age 40-59_cases  Age 60-79_cases  Age 80+_cases  \
# 0                 1.0              1.0              2.0            0.0
# 1                 1.0              1.0              2.0            0.0
# 2                 1.0              1.0              2.0            0.0
# 3                 1.0              1.0              2.0            0.0
# 4                 1.0              1.0              2.0            0.0
# ...               ...              ...              ...            ...
# 6550             40.0             25.0              7.0            2.0
# 6551             40.0             25.0              7.0            2.0
# 6552              NaN              NaN              NaN            NaN
# 6553              NaN              NaN              NaN            NaN
# 6554              NaN              NaN              NaN            NaN
#
#       Positive UnkAge_cases dtm_updated_cases  ...  Age 40-59_hospitalization  \
# 0                       0.0    7/5/2020 15:36  ...                        1.0
# 1                       0.0    7/5/2020 15:36  ...                        1.0
# 2                       0.0    7/5/2020 15:36  ...                        1.0
# 3                       0.0    7/5/2020 15:36  ...                        1.0
# 4                       0.0    7/5/2020 15:36  ...                        1.0
# ...                     ...               ...  ...                        ...
# 6550                    0.0    7/5/2020 15:36  ...                        1.0
# 6551                    0.0    7/5/2020 15:36  ...                        0.0
# 6552                    NaN               NaN  ...                        NaN
# 6553                    NaN               NaN  ...                        NaN
# 6554                    NaN               NaN  ...                        NaN
#
#       Age 60-79_hospitalization  Age 80+_hospitalization  \
# 0                           0.0                      0.0
# 1                           3.0                      0.0
# 2                           0.0                      0.0
# 3                           0.0                      0.0
# 4                           0.0                      0.0
# ...                         ...                      ...
# 6550                        0.0                      0.0
# 6551                        0.0                      0.0
# 6552                        NaN                      NaN
# 6553                        NaN                      NaN
# 6554                        NaN                      NaN
#
#       Positive UnkAge_hospitalization  dtm_updated_hospitalization  exists  \
# 0                                 0.0          2020/07/05 15:36:42    both
# 1                                 0.0          2020/07/05 15:36:42    both
# 2                                 0.0          2020/07/05 15:36:42    both
# 3                                 0.0          2020/07/05 15:36:42    both
# 4                                 0.0          2020/07/05 15:36:42    both
# ...                               ...                          ...     ...
# 6550                              0.0          2020/07/05 15:36:42    both
# 6551                              0.0          2020/07/05 15:36:42    both
# 6552                              NaN                          NaN     NaN
# 6553                              NaN                          NaN     NaN
# 6554                              NaN                          NaN     NaN
#
#       Political_Party Percent Below Poverty Level Household Income Median  \
# 0          Republican                        25.2                 49142.0
# 1          Republican                        25.2                 49142.0
# 2          Republican                        25.2                 49142.0
# 3          Republican                        25.2                 49142.0
# 4          Republican                        25.2                 49142.0
# ...               ...                         ...                     ...
# 6550              NaN                         NaN                     NaN
# 6551              NaN                         NaN                     NaN
# 6552       Republican                        18.8                 41924.0
# 6553       Republican                        11.6                 52525.0
# 6554       Republican                        12.9                 50744.0
#
#      Household Income Mean
# 0                  61370.0
# 1                  61370.0
# 2                  61370.0
# 3                  61370.0
# 4                  61370.0
# ...                    ...
# 6550                   NaN
# 6551                   NaN
# 6552               54815.0
# 6553               57202.0
# 6554               64904.0
#
# [6555 rows x 34 columns]

# %%
mergedf3["County"].value_counts()
# Out:
# Snohomish County       576
# King County            550
# Yakima County          420
# Pierce County          420
# Benton County          361
# Franklin County        360
# Clark County           342
# Whatcom County         340
# Spokane County         340
# Grant County           300
# Skagit County          300
# Thurston County        285
# Cowlitz County         247
# Kitsap County          209
# Island County          204
# Chelan County          180
# Lewis County           135
# Douglas County         126
# Walla Walla County     119
# Adams County           102
# Klickitat County        96
# Grays Harbor County     80
# Jefferson County        77
# Mason County            68
# Okanogan County         68
# Stevens County          60
# Kittitas County         54
# Clallam County          45
# Unassigned              20
# Pacific County          16
# Whitman County          13
# Skamania County         10
# San Juan County          9
# Asotin County            8
# Pend Oreille County      5
# Wahkiakum County         4
# Columbia County          3
# Garfield County          1
# Lincoln County           1
# Ferry County             1
# Name: County, dtype: int64

# %%
mergedf3.to_csv("covid_merged.csv")
