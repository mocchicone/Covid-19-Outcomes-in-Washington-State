# %%
import pandas as pd
import numpy as np
import datetime
from functools import reduce

# %%
data = pd.read_csv("Census_Wash_Counties_Income_Poverty.csv")
data.columns
# Out:
# Index(['GEO_ID', 'NAME', 'DP03_0001E', 'DP03_0001M', 'DP03_0001PE',
#        'DP03_0001PM', 'DP03_0002E', 'DP03_0002M', 'DP03_0002PE', 'DP03_0002PM',
#        ...
#        'DP03_0135PE', 'DP03_0135PM', 'DP03_0136E', 'DP03_0136M', 'DP03_0136PE',
#        'DP03_0136PM', 'DP03_0137E', 'DP03_0137M', 'DP03_0137PE',
#        'DP03_0137PM'],
#       dtype='object', length=550)

# %%
data.head()

data["County Name"] = pd.Series(data["NAME"]).str.split(",").str[0]
data.head()
# Out:
#            GEO_ID                        NAME  \
# 0              id        Geographic Area Name
# 1  0500000US53011    Clark County, Washington
# 2  0500000US53015  Cowlitz County, Washington
# 3  0500000US53041    Lewis County, Washington
# 4  0500000US53045    Mason County, Washington
#
#                                           DP03_0001E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                             380248
# 2                                              86221
# 3                                              64562
# 4                                              54199
#
#                                           DP03_0001M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                               1154
# 2                                                563
# 3                                                576
# 4                                                413
#
# ...

# %%
# grab columns that we want
new_df = data.loc[:,["DP03_0119PE", "DP03_0021PE", "DP03_0051E", "County Name"]]
new_df[["County Name", "DP03_0021PE", "DP03_0051E", "DP03_0119PE"]]
rename_df = new_df.rename(columns={"County Name": "County Name", 
                                      "DP03_0021PE": "Public Transportation",
                                      "DP03_0051E": "Household Income (mean)",
                                      "DP03_0119PE": "Percentage Poverty"})
rename_df
census_df = rename_df.drop([0])
census_df[["County Name", "Percentage Poverty", "Public Transportation", "Household Income (mean)"]]
# Out:
#             County Name Percentage Poverty Public Transportation  \
# 1          Clark County                5.4                   2.6
# 2        Cowlitz County                8.5                     0
# 3          Lewis County                7.7                   0.8
# 4          Mason County                8.7                   1.1
# 5         Pierce County                5.2                   4.3
# 6           King County                5.5                  14.6
# 7         Yakima County               12.7                   0.2
# 8         Benton County                6.5                   0.8
# 9        Spokane County                7.9                   3.3
# 10       Whatcom County                8.7                   2.2
# 11        Chelan County                6.7                   0.3
# 12  Grays Harbor County                9.2                   0.5
# 13      Franklin County               11.1                   0.5
# ...

# %%
census_df.to_csv("census.csv", index=False, header=True)
